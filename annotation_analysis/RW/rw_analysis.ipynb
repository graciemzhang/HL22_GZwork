# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import re
import warnings
import datetime

import matplotlib.pyplot as plt 
from matplotlib.backends.backend_pdf import PdfPages

warnings.filterwarnings("ignore")
import pickle
import scipy
from scipy import signal

# %%
#loads in functions
# %run ../Files/functions.ipynb

# %% [markdown]
# ### Loading in Files

# %%
filename = '../Files/optical_flow_df'
infile = open(filename,'rb')
of_df = pickle.load(infile)
infile.close()

# %%
filename = '../Files/mod_df'
infile = open(filename,'rb')
mod_df = pickle.load(infile)
infile.close()

# %%
filename = '../Files/mouse_vids'
infile = open(filename,'rb')
mouse_vids = pickle.load(infile)
infile.close()

# %%
flicker_vids = pd.read_csv("../Files/WtoR_videos.csv")

# %%
tvp = pd.read_csv("../Files/twitch_vs_pause.csv")

# %% [markdown]
# ### Exploration of dataframe

# %%
mod_df.columns
# Out:
# Index(['dataset_name', 'video_filename', 'flicker_flavor',
#        'percentile_normalized_flow', 'median_filter_pnf', 'traces'],
#       dtype='object')

# %% [markdown]
# ### Extracting R/W

# %%
video_names = mod_df["video_filename"].unique()

# %%
#stores all rw flickers
rw_flickers = {}

# %%
#stores all optical flow values corresponding to flicker intervals
rw_of = {}

# %%
#stores all median_filter values corresponding to flicker intervals
rw_pnf = {}

# %%
for video_name in video_names:
    video_df = mod_df.loc[mod_df['video_filename'] == video_name]
    flicker = video_df['flicker_flavor'].values
    groups = find_groups(flicker).get('REM_WITHIN_WAKE')
    
    vid_flickers = []
    if groups != None:
        for group in groups:
            if calculate_frames(group[0], group[1], 150) != None:
                vid_flickers.append(group)
        rw_flickers[video_name] = vid_flickers
    else:
        rw_flickers[video_name] = None

# %%
for i, video_name in enumerate(video_names):
    video_df = mod_df.loc[mod_df['video_filename'] == video_name]
    cur_flickers = rw_flickers.get(video_name)
    if cur_flickers != None:
        for flicker in cur_flickers:
            name, ants = annotations(video_name, video_df, flicker, 150, 'percentile_normalized_flow')
            rw_of[name] = ants
    else:
        rw_of[video_name] = None

# %%
for i, video_name in enumerate(video_names):
    video_df = mod_df.loc[mod_df['video_filename'] == video_name]
    cur_flickers = rw_flickers.get(video_name)
    if cur_flickers != None:
        for flicker in cur_flickers:
            name, ants = annotations(video_name, video_df, flicker, 150, 'median_filter_pnf')
            rw_pnf[name] = ants
    else:
        rw_pnf[video_name] = None

# %% [markdown]
# ### Functions for Plotting

# %%
#cleans video name
def clean_list(raw_list):
    cleaned_vids = [x for x in raw_list if str(x) != 'nan']
    cleaned_vids = [(x + ".mp4") if len(x.split(".")) < 2 else x for x in cleaned_vids]
    
    return cleaned_vids

# %%
def plot_flow(video_name, arr):
    fig, ax = plt.subplots()
    vid_arr = arr.get(vid)

    plt.title(vid)
    
    ax.set_xticks(np.arange(0, 315, 15))
    ax.set_xticklabels(np.arange(-10, 11, 1))
    
    ax.set_ylim([0, 5.0])
    plt.plot(vid_arr)
    
    plt.show()

# %% [markdown]
# ### Optical Flow Plots

# %%
flicker_vids
# Out:
#                                            CAF26  \
# 0     e3v819c-20200807T1509-1609_f3128-f3148.mp4
# 1     e3v819c-20200807T1609-1709_f4344-f4377.mp4
# 2   e3v819c-20200807T1609-1709_f13545-f13555.mp4
# 3   e3v819c-20200807T1609-1709_f13812-f13817.mp4
# 4   e3v819c-20200807T1609-1709_f13821-f13838.mp4
# 5   e3v819c-20200807T1609-1709_f16213-f16226.mp4
# 6   e3v819c-20200807T1709-1809_f33907-f33916.mp4
# 7   e3v819c-20200807T2109-2209_f25048-f25062.mp4
# 8     e3v819c-20200808T0209-0309_f2732-f2742.mp4
# 9     e3v819c-20200808T0209-0309_f4200-f4268.mp4
# 10    e3v819c-20200808T0209-0309_f4936-f4943.mp4
# 11    e3v819c-20200808T0209-0309_f4954-f4967.mp4
# 12    e3v819c-20200808T0209-0309_f6435-f6449.mp4
# 13  e3v819c-20200808T0209-0309_f12801-f12816.mp4
# 14  e3v819c-20200808T0209-0309_f31576-f31588.mp4
# 15  e3v819c-20200808T0509-0609_f17306-f17315.mp4
# 16  e3v819c-20200808T0509-0609_f17328-f17367.mp4
# 17  e3v819c-20200808T0709-0809_f11652-f11669.mp4
# 18  e3v819c-20200808T0809-0909_f40558-f40567.mp4
# 19  e3v819c-20200808T1109-1209_f45118-f45130.mp4
# 20      e3v819c-20200808T1109-1209_f46895-f46909
#
#                                                CAF34  \
# 0       e3v819c-20200827T171404-181405_f670-f679.mp4
# 1   e3v819c-20200827T171404-181405_f47977-f48007.mp4
# 2   e3v819c-20200827T181405-191405_f11469-f11483.mp4
# 3   e3v819c-20200827T181405-191405_f12633-f12641.mp4
# 4   e3v819c-20200827T181405-191405_f20078-f20084.mp4
# 5     e3v819c-20200827T191405-201406_f8734-f8749.mp4
# 6   e3v819c-20200827T191405-201406_f42115-f42144.mp4
# 7   e3v819c-20200827T201406-211406_f47171-f47192.mp4
# 8     e3v819c-20200827T221407-231408_f1719-f1728.mp4
# 9     e3v819c-20200827T221407-231408_f3770-f3781.mp4
# 10  e3v819c-20200828T001408-011409_f39764-f39773.mp4
# 11  e3v819c-20200828T031411-041411_f37063-f37072.mp4
# 12  e3v819c-20200828T041411-051412_f14507-f14519.mp4
# 13  e3v819c-20200828T061413-071414_f13400-f13408.mp4
# 14  e3v819c-20200828T111417-121418_f23615-f23626.mp4
# 15  e3v819c-20200828T111417-121418_f32019-f32021.mp4
# 16  e3v819c-20200828T131419-141419_f26915-f26935.mp4
# 17  e3v819c-20200828T131419-141419_f32067-f32070.mp4
# 18  e3v819c-20200828T141419-151420_f38155-f38176.mp4
# 19  e3v819c-20200828T141419-151420_f40068-f40099.mp4
# 20                                               NaN
#
#                                            CAF42
# 0   e3v81a6-20200914T182237-192238_f36758-f36781
# 1   e3v81a6-20200914T192238-202238_f17837-f17849
# 2     e3v81a6-20200914T202238-212239_f4627-f4643
# 3   e3v81a6-20200914T212239-222240_f24414-f24427
# 4   e3v81a6-20200914T232241-002242_f37820-f37835
# 5   e3v81a6-20200915T002242-012242_f43313-f43326
# 6   e3v81a6-20200915T022243-032244_f28799-f28808
# 7   e3v81a6-20200915T022243-032244_f43964-f43976
# 8   e3v81a6-20200915T042245-052246_f36200-f36214
# 9     e3v81a6-20200915T052246-062246_f2662-f2668
# 10  e3v81a6-20200915T052246-062246_f16565-f16602
# 11  e3v81a6-20200915T052246-062246_f35563-f35573
# 12    e3v81a6-20200915T062246-072247_f4108-f4116
# 13  e3v81a6-20200915T062246-072247_f48753-f48763
# 14  e3v81a6-20200915T072247-082248_f12148-f12148
# 15  e3v81a6-20200915T092249-102249_f14127-f14133
# 16  e3v81a6-20200915T092249-102249_f26430-f26437
# 17  e3v81a6-20200915T092249-102249_f31573-f31591
# 18  e3v81a6-20200915T112250-122251_f14180-f14211
# 19    e3v81a6-20200915T152253-162254_f5221-f5243
# 20                                           NaN

# %%
raw_vids = []

# %%
for column in flicker_vids:
    raw_vids.extend(flicker_vids[column].values)

# %%
#cleans all video names
cleaned_vids = clean_list(raw_vids)

# %%
# pdf = PdfPages('of_plots.pdf')

# %%
#plots optical flow
for vid in cleaned_vids:
    plot_flow(vid, rw_of)

# %%
#plots median filter values
for vid in cleaned_vids:
    plot_flow(vid, rw_pnf)

# %% [markdown]
# ### Twitch or Pause Plots

# %%
tvp
# Out:
#                                          twitch  \
# 0  e3v81a6-20200914T192238-202238_f17837-f17849
# 1  e3v81a6-20200914T232241-002242_f37820-f37835
# 2  e3v81a6-20200915T042245-052246_f36200-f36214
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
#
#                                           pause
# 0  e3v81a6-20200914T182237-192238_f36758-f36781
# 1  e3v81a6-20200915T022243-032244_f28799-f28808
# 2    e3v81a6-20200915T052246-062246_f2662-f2668
# 3  e3v81a6-20200915T072247-082248_f12148-f12148
# 4  e3v81a6-20200915T092249-102249_f14127-f14133
# 5  e3v81a6-20200915T092249-102249_f26430-f26437
# 6    e3v81a6-20200915T152253-162254_f5221-f5243

# %%
twitch = tvp["twitch"].values.tolist()
pause = tvp["pause"].values.tolist()

# %%
cleaned_twitch = clean_list(twitch)
cleaned_pause = clean_list(pause)

# %%
# twitch_pdf = PdfPages('twitch_plots.pdf')

# %%
# pause_pdf = PdfPages('pause_plots.pdf')

# %%
#plots only intervals that correlate to a twitch behavior
for vid in cleaned_twitch:
    plot_flow(vid, rw_of)

# %%
#plots only intervals that correlate to a pause behavior
for vid in cleaned_pause:
    plot_flow(vid, rw_of)
