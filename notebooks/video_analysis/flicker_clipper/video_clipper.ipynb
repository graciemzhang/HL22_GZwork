# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '../Utilities')
from tqdm import tqdm
import warnings
import time as t
import os
import cv2
import glob
import argparse
from os.path import isfile, join
from PIL import Image
import multiprocessing as mp
from PIL import ImageDraw
from PIL import ImageFont
from itertools import groupby
from operator import itemgetter
warnings.filterwarnings("ignore")
import pickle

# %% [markdown]
# ### Load and Process Dataframe

# %%
filename = '../Files/optical_flow'
infile = open(filename,'rb')
df = pickle.load(infile)
infile.close()

# %%
df['dataset_name'].unique()
# Out:
# array(['CAF26', 'CAF34', 'CAF42', 'CAF69', 'EAB40', 'EAB50_5state',
#        'CAF99', 'CAF106', 'CAF77'], dtype=object)

# %%
caf26_df = df[df['dataset_name'] == 'CAF26']
caf34_df = df[df['dataset_name'] == 'CAF34']
caf42_df = df[df['dataset_name'] == 'CAF42']
caf69_df = df[df['dataset_name'] == 'CAF69']
eab40_df = df[df['dataset_name'] == 'EAB40']
eab50_df = df[df['dataset_name'] == 'EAB50_5state']
caf99_df = df[df['dataset_name'] == 'CAF99']
caf106_df = df[df['dataset_name'] == 'CAF106']
caf77_df = df[df['dataset_name'] == 'CAF77']

# %% [markdown]
# ### Set Up File Paths

# %%
os.chdir(os.path.dirname(os.getcwd()))

# %%
cwd_path = os.getcwd()
documents_path = '/Users/graciezhang/Documents/Hengen-Lab'
external_path = f'{documents_path}/Hengen-Lab-Work'
buffer_path = f'{documents_path}/Hengen-Lab-Work/buffer'
put_path = f'{documents_path}/Hengen-Lab-Work/Notebooks/video_clipper/Mice_Clips'
remote_path = "/media/HlabShare/Aidan_Work/flicker_videos/"

# %%
# 77 is the 56 gig video
fps_animals = {"CAF99": 30,"CAF106": 30,"CAF26":15, "EAB40": 15, "EAB50": 15, "CAF69": 30, "CAF42": 15, "CAF34": 15, "CAF77" : 15}

# %% [markdown]
# ### Open Video and Check Video

# %%
#buffer directory outside directory of notebook
def convert_frames_to_video(pathIn, pathOut, fps, mouse_name):
    frame_array = []
    os.chdir(cwd_path)
    files = [f for f in os.listdir(pathIn) if isfile(join(pathIn, f))]
    
    os.chdir(buffer_path)
    if len(files) <= 1: return
    
    files = np.sort([int(i[:-4]) for i in files])
    files = [str(i)+'.jpg' for i in files]
    
    for i in range(1,len(files)):
        filename= files[i]
        img = cv2.imread(filename)
        height, width, layers = img.shape
        size = (width,height)
        frame_array.append(img)
        
    os.chdir(put_path)
    cur_dir = os.getcwd()
    out = cv2.VideoWriter(cur_dir + f'/{mouse_name}' + pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
    
    for i in range(len(frame_array)): out.write(frame_array[i])
    out.release()

# %%
def flick(flicker):
    if flicker == None: return 'None'
    elif flicker == 'WAKE_WITHIN_NREM': return 'WN'
    elif flicker == 'REM_WITHIN_NREM': return 'RN'
    elif flicker == 'NREM_WITHIN_REM': return 'NR'
    elif flicker == 'NREM_WITHIN_WAKE': return 'NW'
    elif flicker == 'REM_WITHIN_WAKE': return 'RW'
    elif flicker == 'WAKE_WITHIN_REM': return 'WR'

def write_text_frame(frame_name,sleep_state,pred_sleep_state,flicker):
    img = Image.open(frame_name)
    drawer = ImageDraw.Draw(img)
    os.chdir(cwd_path)
    font_path = documents_path+'/Hengen-Lab-Work/Notebooks/video_clipper/SpaceMono-Regular.ttf'
    font = ImageFont.truetype(font_path, 15)
    os.chdir(buffer_path)
    drawer.text((img.size[0]*0.7, img.size[1]*0.15), f"Sleep State: {num_sleep_conv(sleep_state)}", fill=(255,255,255),font=font)
    drawer.text((img.size[0]*0.7, img.size[1]*0.25), f"Flicker Type: {flick(flicker)}", fill=(255,255,255),font=font)
    drawer.text((img.size[0]*0.7, img.size[1]*0.2), f"Pred Sleep State: {num_sleep_conv(pred_sleep_state)}", fill=(255,255,255),font=font)
#     if type(behavior) == list:
#         loc_behavior = (num_cat(behavior[0])) if behavior[0] < 10 else 'None'
#         reg_behavior = 'None' if behavior[1] < 10 else (num_cat(behavior[1]))
#     else:
#         loc_behavior = (num_cat(behavior)) if behavior < 10 else 'None'
#         reg_behavior = 'None' if behavior < 10 else (num_cat(behavior))
#     drawer.text((img.size[0]*0.7, img.size[1]*0.25), f"LoConst: None", fill=(255,255,255),font=font)
#     drawer.text((img.size[0]*0.7, img.size[1]*0.3), f"Regular: None", fill=(255,255,255),font=font)
    img.save(frame_name)

# %% [markdown]
# ### Do all  Videos for an animal

# %%
def num_sleep_conv(state): return 'W' if state == 0 else ('N' if state == 1 else 'R')

# %%
def num_flick(flicker):
    if flicker == 0: return 'None'
    elif flicker == 1: return 'NW'
    elif flicker == 2: return 'RW'
    elif flicker == 3: return 'NR'
    elif flicker == 4: return 'WR'
    elif flicker == 5: return 'RN'
    elif flicker == 6: return 'WN'

# %%
def num_cat(behavior):
    if behavior == 1: return 'Nest'
    elif behavior == 2: return 'PBall'
    elif behavior == 3: return 'PBox'
    elif behavior == 4: return 'RBall'
    elif behavior == 5: return 'RBox'
    elif behavior == 6: return 'Drink'
    elif behavior == 7: return 'Chew'
    elif behavior == 8: return 'Port'
    elif behavior == 9: return 'Groom'
    elif behavior == 10: return 'CFront'
    elif behavior == 11: return 'CPort'
    elif behavior == 12: return 'Dig'
    elif behavior == 13: return 'Motion'
    elif behavior == 14: return 'MPM'
    elif behavior == 15: return 'Rear'
    elif behavior == 16: return 'Stretch'
    elif behavior == 17: return 'Twitch'

# %%
def flushBuffer(): # flush all frames from folder
    dir = buffer_path
    for f in os.listdir(buffer_path):
        os.remove(os.path.join(buffer_path, f))

# %%
def flushClips(mouse_name): # flush all frames from folder
    dir = f'{put_path}/{mouse_name}'
    for f in os.listdir(dir):
        os.remove(os.path.join(dir, f))

# %%
def find_groups(flickers):
    flickers = sorted(set(flickers))
    gaps = [[s, e] for s, e in zip(flickers, flickers[1:]) if s+1 < e]
    edges = iter(flickers[:1] + sum(gaps, []) + flickers[-1:])
    return list(zip(edges, edges))

def create_flicker_clips(df,animal):
    #start_frame = 1
    flickers = np.array(np.nonzero(np.array(df.flicker_flavor))[0])
    flicker_groups = find_groups(flickers) # 15 fps, 54000
    
    os.chdir(put_path)
    
    os.chdir(cwd_path)
    
    for group in flicker_groups:
        start_frame = group[0]
        end_frame = group[1]
        original_start = start_frame # 15 fps, 54000
        original_end = end_frame # 15 fps, 54000
        # df idx locations
        start_frame_idx = int(((original_start+original_end)/2)-(30*15)) # df idx
        end_frame_idx = int(((original_start+original_end)/2)+(30*15)) # df idx location
        idx_locations = np.arange(start_frame_idx, end_frame_idx+1, 1)
        if idx_locations[-1] > 54000 or idx_locations[0] < 0 or idx_locations[-1] < 0 or idx_locations[0] > 54000: continue
        # vid idx locations
        vid_start_idx = int(start_frame_idx*(fps_animals[animal]/15)-1) if fps_animals[animal] != 15 else start_frame_idx
        vid_end_idx = int(end_frame_idx*(fps_animals[animal]/15)) if fps_animals[animal] != 15 else end_frame_idx
        i = 0
        idx = 0
        if df.iloc[start_frame].flicker_flavor == 'WAKE_WITHIN_NREM':
            for frame in tqdm(range(vid_start_idx,vid_end_idx-1 if fps_animals[animal] !=15 else vid_end_idx)): # vid location
                os.chdir(buffer_path)
                cap.set(1, frame)
                ret, still = cap.read()
                frame_name = f'{frame}.jpg'
                cv2.imwrite(frame_name, still)
                flicker = df.iloc[idx_locations[idx]].flicker_flavor
                sleep_state = df.iloc[idx_locations[idx]].label_wnr_012
                pred_sleep_state = df.iloc[idx_locations[idx]].predicted_wnr_012
                write_text_frame(frame_name,sleep_state,pred_sleep_state,flicker)
                if fps_animals[animal] != 15: 
                    if i % (fps_animals[animal]/15) == 1: idx+=1
                else: idx+=1
                i+=1
                
            os.chdir(buffer_path)
            
            ds_store_file_location = f'{buffer_path}/.DS_Store'
            if os.path.isfile(ds_store_file_location):
                os.remove(ds_store_file_location)

            
            convert_frames_to_video(buffer_path, f'/{video_name}_f{original_start}-f{original_end}.mp4',fps_animals[animal], animal)
            
            os.chdir(buffer_path)
            
            flushBuffer()

# %%
for video in caf106_df.video_filename.unique():
    cur_df = caf106_df[caf106_df['video_filename'] == video]
    mouse_name = 'CAF106'
    os.chdir(external_path)
    cur_dir = os.getcwd()
    video_path = f'{cur_dir}/videos/{mouse_name}/{video}'
    cap = cv2.VideoCapture(video_path)
    video_name = video
    cur_df = df[df['video_filename'] == video_name]
    video_name = video_name[:len(video_name)-4]
    cur_df = df[df['video_filename'] == video]
    create_flicker_clips(cur_df, mouse_name)
# Out:
# 100%|███████████████████████████████████████| 1800/1800 [01:45<00:00, 16.99it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:58<00:00, 15.25it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:51<00:00, 16.09it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:59<00:00, 15.11it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:41<00:00, 17.71it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:56<00:00, 15.41it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:55<00:00, 15.52it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:51<00:00, 16.12it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:07<00:00, 14.17it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:20<00:00, 12.79it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:46<00:00, 10.78it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:26<00:00, 12.30it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:20<00:00, 12.85it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:29<00:00, 12.02it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:41<00:00, 11.14it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:38<00:00, 11.32it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:37<00:00, 11.45it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:21<00:00, 12.70it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:20<00:00, 12.78it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:34<00:00, 11.69it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:41<00:00, 11.12it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:33<00:00, 11.75it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:31<00:00, 11.86it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:04<00:00, 14.49it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:05<00:00, 14.39it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:28<00:00, 12.08it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:43<00:00, 11.02it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:55<00:00, 10.28it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:51<00:00, 10.47it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:33<00:00, 11.72it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:39<00:00, 11.25it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:37<00:00, 11.40it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:17<00:00, 13.06it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:19<00:00, 12.89it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:17<00:00, 13.05it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:17<00:00, 13.12it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [37:35<00:00,  1.25s/it]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:15<00:00, 13.32it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:25<00:00, 12.36it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:14<00:00, 13.40it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:10<00:00, 13.83it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:09<00:00, 13.94it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:09<00:00, 13.95it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:57<00:00, 15.26it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:47<00:00, 16.70it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:14<00:00, 13.39it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:07<00:00, 14.09it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:04<00:00, 14.46it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:53<00:00, 15.80it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:51<00:00, 16.22it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:59<00:00, 15.05it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:52<00:00, 15.97it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:43<00:00, 17.40it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:40<00:00, 17.90it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:40<00:00, 17.93it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:39<00:00, 18.04it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:01<00:00, 14.82it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:10<00:00, 13.79it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:07<00:00, 14.08it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:57<00:00, 15.36it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:11<00:00, 13.70it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:35<00:00, 11.57it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:22<00:00, 12.62it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:53<00:00, 15.79it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:56<00:00, 15.49it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:05<00:00, 14.33it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:54<00:00, 15.76it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:58<00:00, 15.14it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:05<00:00, 14.34it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:33<00:00, 11.74it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:18<00:00, 12.96it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:46<00:00, 16.97it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:45<00:00, 17.07it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:57<00:00, 15.32it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:52<00:00, 15.98it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:08<00:00, 14.01it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:00<00:00, 14.95it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:22<00:00, 12.65it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:12<00:00, 13.54it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:10<00:00, 13.80it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:05<00:00, 14.30it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:04<00:00, 14.40it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:44<00:00, 17.24it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:45<00:00, 17.01it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:41<00:00, 17.68it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:07<00:00, 14.15it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:02<00:00, 14.68it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:58<00:00, 15.20it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:57<00:00, 15.33it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:22<00:00, 12.65it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:16<00:00, 13.16it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:14<00:00, 13.42it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:10<00:00, 13.82it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|█████████████████████████████████████| 1800/1800 [1:05:12<00:00,  2.17s/it]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [50:25<00:00,  1.68s/it]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|█████████████████████████████████████| 1800/1800 [7:07:03<00:00, 14.24s/it]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|█████████████████████████████████████| 1800/1800 [8:38:57<00:00, 17.30s/it]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:02<00:00, 14.71it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:11<00:00, 13.70it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:12<00:00, 13.57it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:05<00:00, 14.29it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:16<00:00, 13.23it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:23<00:00, 12.55it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:13<00:00, 13.44it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:36<00:00, 11.49it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [06:04<00:00,  4.94it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:48<00:00,  7.88it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:59<00:00,  7.51it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:57<00:00,  7.58it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:29<00:00,  6.68it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [05:03<00:00,  5.93it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:54<00:00,  6.11it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:45<00:00, 17.07it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:09<00:00, 13.85it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:10<00:00, 13.74it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:01<00:00, 14.80it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:59<00:00, 15.06it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:55<00:00, 15.54it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:04<00:00, 14.42it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:02<00:00, 14.64it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:05<00:00, 14.36it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:57<00:00, 15.29it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:51<00:00, 16.13it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:49<00:00, 16.50it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:12<00:00, 13.61it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:00<00:00, 14.99it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:23<00:00, 12.51it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:23<00:00, 12.58it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:20<00:00, 12.78it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:24<00:00, 12.45it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:27<00:00, 12.16it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:30<00:00, 11.93it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:31<00:00, 11.85it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:24<00:00, 12.47it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:16<00:00, 13.18it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:18<00:00, 12.96it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:09<00:00, 13.89it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:26<00:00, 12.32it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:39<00:00,  6.44it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [05:06<00:00,  5.88it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:45<00:00,  6.31it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:41<00:00,  6.40it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:40<00:00,  6.42it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [05:01<00:00,  5.97it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:45<00:00,  6.30it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:44<00:00,  6.33it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:39<00:00,  6.45it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:44<00:00,  6.32it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:20<00:00,  8.99it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:38<00:00,  8.25it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:11<00:00,  9.39it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:31<00:00,  8.49it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:39<00:00,  8.19it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:16<00:00,  7.01it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:03<00:00,  7.40it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:20<00:00,  6.90it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:23<00:00,  6.82it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:30<00:00,  6.67it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:02<00:00,  7.43it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:23<00:00,  8.86it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:41<00:00,  8.11it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:04<00:00,  7.35it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:10<00:00,  9.44it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:10<00:00,  7.18it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:37<00:00,  8.28it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:22<00:00,  8.91it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:27<00:00,  8.67it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:00<00:00,  9.96it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:46<00:00, 10.82it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:08<00:00,  7.24it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [05:30<00:00,  5.45it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:50<00:00, 10.55it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:08<00:00,  9.55it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:57<00:00,  6.05it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:10<00:00,  7.20it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:58<00:00,  6.03it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:42<00:00,  6.38it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:35<00:00,  6.54it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [05:01<00:00,  5.97it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [05:00<00:00,  5.99it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:55<00:00,  6.09it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:47<00:00,  6.25it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:47<00:00,  6.27it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:56<00:00,  6.07it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [05:01<00:00,  5.97it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:53<00:00,  6.14it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [02:37<00:00, 11.44it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:54<00:00,  7.68it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:23<00:00,  6.83it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:03<00:00,  7.40it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [05:03<00:00,  5.93it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [05:36<00:00,  5.34it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [05:53<00:00,  5.09it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [05:17<00:00,  5.67it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:50<00:00,  6.20it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [09:26<00:00,  3.18it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:47<00:00,  6.26it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:46<00:00,  6.28it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:24<00:00,  6.81it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [01:56<00:00, 15.42it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:46<00:00,  6.28it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [03:09<00:00,  9.48it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:46<00:00,  6.28it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:43<00:00,  6.34it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:41<00:00,  6.39it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [05:08<00:00,  5.83it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:48<00:00,  6.23it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [04:34<00:00,  6.55it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|███████████████████████████████████████| 1800/1800 [22:29<00:00,  1.33it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|█████████████████████████████████████| 1800/1800 [8:00:26<00:00, 16.01s/it]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|█████████████████████████████████████| 1800/1800 [3:06:31<00:00,  6.22s/it]

# %%
flushBuffer()

# %%
flushClips('CAF42')
